# %% [markdown]
# # Project One - visualization future stock price/test portfolio

# %%
# Initial imports
import os
import requests
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
import yfinance as yf
from datetime import datetime 
import pandas_datareader.data as web
from MCForecastTools import MCSimulation
import matplotlib.pyplot as plt
from matplotlib import style

# %matplotlib inline

style.use('ggplot')

# %%
# Load .env enviroment variables
load_dotenv("/Users/brennanseanm/Jupyter-Workspace/.env")
# Out:
# True

# %% [markdown]
# ## Part 1 - Pull in data using Yahoo Finance

# %%
#Downloading stock infromatino from Yahoo Finance
#aapl_df = yf.download("aapl", start='2016-04-05', end="2021-04-01")
#tsla_df2 = yf.download("tsla", start='2015-03-03', end="2019-04-23")
#amzn_df2 = yf.download("amzn", start='2015-03-03', end="2019-04-23")
#msft_df2 = yf.download("msft", start='2015-03-03', end="2019-04-23")
#goog_df2 = yf.download("goog", start='2015-03-03', end="2019-04-23")

#Dropping extra columns and renaming close column to be able to combine data into a clean data frame for analysis
#aapl_df = aapl_df.drop(columns = ['Open', 'High', 'Low', 'Close', 'Volume'])
#tsla_df2 = tsla_df2.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'TSLA'})
#amzn_df2 = amzn_df2.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'AMZN'})
#msft_df2 = msft_df2.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'MSFT'})
#goog_df2 = goog_df2.drop(columns = ['Open', 'High', 'Low', 'Adj Close', 'Volume']).rename(columns = {'Close':'GOOG'})

# %%
#Set the start date and end date to pull up to 5 years of data
startdate = '2016-04-05'
today = datetime.today().strftime('%Y-%m-%d')

startdate, today
# Out:
# ('2016-04-05', '2021-04-07')

# %%
#Pull stock price via Yahoo using DataReader to test MC simualation on Stock Price
aapl_price = web.DataReader('AAPL', data_source = 'yahoo', start = startdate, end = today)['Adj Close']

# %%
#Display data for the adjusted close price from Yahoo
aapl_price
# Out:
# Date
# 2016-04-05     25.533810
# 2016-04-06     25.801216
# 2016-04-07     25.238501
# 2016-04-08     25.266407
# 2016-04-11     25.350115
#                  ...
# 2021-03-31    122.150002
# 2021-04-01    123.000000
# 2021-04-05    125.900002
# 2021-04-06    126.209999
# 2021-04-07    127.900002
# Name: Adj Close, Length: 1261, dtype: float64

# %%
#Calculate daily return and volatiltiy so these variables can be leveraged for the MC Simulation
daily_return = aapl_price.pct_change()
daily_vol = daily_return.std()

#View data to validate the calculation values
daily_return, daily_vol
# Out:
# (Date
#  2016-04-05         NaN
#  2016-04-06    0.010473
#  2016-04-07   -0.021810
#  2016-04-08    0.001106
#  2016-04-11    0.003313
#                  ...
#  2021-03-31    0.018766
#  2021-04-01    0.006959
#  2021-04-05    0.023577
#  2021-04-06    0.002462
#  2021-04-07    0.013390
#  Name: Adj Close, Length: 1261, dtype: float64,
#  0.01910296518697101)

# %%
#Define a value for last price to leverage in the MC simulation graph
last_price_aapl = aapl_price[-1]
last_price_aapl
# Out:
# 127.9000015258789

# %%
#Monte Carlo Simulation setup with plan to run 50 scenarios for one year stock price 
num_simu = 50
num_days = 252

#Create DataFrame for simulation
simulation_df = pd.DataFrame()

# %%
#Function created for MC daily price similation for one year

for x in range(num_simu):
    count = 0
    daily_vol = daily_return.std()
    
    price_series = []
    
    prices = last_price_aapl*(1 + np.random.normal(0, daily_vol))
    price_series.append(prices)
    
    for y in range(num_days):
        if count == 251:
            break
        prices = price_series[count]*(1+np.random.normal(0, daily_vol))
        price_series.append(prices)
        count += 1
    
    simulation_df[x] = price_series


simulation_df
# Out:
#              0           1           2           3           4           5   \
# 0    130.774999  124.429015  128.997166  128.568792  127.827129  128.495364
# 1    129.448237  122.282547  126.546454  127.591324  132.759589  125.021989
# 2    129.199633  123.827965  128.494229  125.086099  130.431904  125.617399
# 3    136.206889  120.804388  129.926821  124.317470  125.884377  125.137903
# 4    136.194697  123.248946  133.348859  122.925852  124.719988  128.162933
# ..          ...         ...         ...         ...         ...         ...
# 247  106.700723   74.127360  184.633420  115.449739  141.960928  145.618860
# 248  109.982110   72.602975  189.099352  112.779326  141.091205  146.145893
# 249  112.567132   74.278811  193.189168  113.697831  135.692634  145.753864
# 250  111.149868   75.035680  194.387669  117.426543  131.333537  147.141352
# 251  109.253498   75.582864  191.057658  120.030429  132.241446  148.455490
#
#              6           7           8           9   ...          40  \
# 0    129.203368  130.574816  127.963309  129.053458  ...  130.268566
# 1    129.682537  132.533334  129.251573  129.775924  ...  131.660551
# 2    134.859098  135.019891  130.370534  127.984640  ...  130.894823
# 3    137.906482  135.124801  133.898112  128.725755  ...  133.969888
# 4    138.740185  137.376655  135.909610  132.160893  ...  131.229145
# ..          ...         ...         ...         ...  ...         ...
# 247  174.628426  124.100770   91.185400  162.389663  ...   98.483296
# 248  174.488453  126.032876   89.818624  165.824397  ...   96.174961
# 249  174.705350  125.980457   90.246033  164.860837  ...   95.771620
# 250  173.200240  123.294240   90.661741  165.544001  ...   98.169053
# 251  169.914812  120.867686   89.703895  162.379866  ...  101.872099
#
#              41          42          43          44          45          46  \
# 0    130.293210  128.556170  128.045490  126.812219  130.028190  127.671583
# 1    131.514383  126.800962  132.301945  127.683695  130.886064  125.719432
# 2    129.011050  128.574006  132.317003  125.426042  130.838220  128.610881
# 3    131.006106  128.340132  129.145301  125.094868  128.356428  127.246308
# 4    126.468224  122.711454  127.605308  124.598377  129.980634  128.696383
# ..          ...         ...         ...         ...         ...         ...
# 247  102.355315  164.433283   68.318281   61.743949  121.058743  210.678154
# 248  101.608022  165.176562   69.972086   62.886237  123.215026  208.802784
# 249  102.582086  164.703179   72.224147   63.538230  124.217749  203.402223
# 250  105.300552  167.641727   74.358063   62.798755  123.986940  194.562460
# 251  100.595010  169.389151   75.836325   61.820462  121.042268  199.375512
#
#              47          48          49
# 0    127.109256  127.632988  128.649359
# 1    122.024315  127.842811  125.621986
# 2    122.104585  127.785299  127.285678
# 3    117.882325  131.938631  126.928596
# 4    118.086512  133.927501  127.535354
# ..          ...         ...         ...
# 247  131.674237  118.852865  150.768362
# 248  134.644686  116.247191  148.614722
# 249  135.180833  113.922390  151.850522
# 250  135.113646  114.346869  153.688790
# 251  132.457072  116.369272  151.172258
#
# [252 rows x 50 columns]

# %%
#Graph results to display future price volitity in the model
fig = plt.figure(figsize=(20,10))
fig.suptitle('Monte Carlo Simulation: Apple Future Stock Price')
plt.plot(simulation_df, lw = 1)
plt.axhline(y = last_price_aapl, color = 'r', linestyle = '-')
plt.xlabel('Day')
plt.ylabel('Price')
plt.show()

# %%
# Calculate 95% confidence intervals for final cumulative returns
confidence_interval = simulation_df.iloc[-1, :].quantile(q=[0.025, 0.975])

#Calculate and display confidence metrics 
metrics = simulation_df.iloc[-1].describe()
ci_series = confidence_interval
ci_series.index = ["95% CI Lower","95% CI Upper"]
final_stats = metrics.append(ci_series)
final_stats
# Out:
# count            50.000000
# mean            134.440133
# std              45.353226
# min              57.330673
# 25%             109.441146
# 50%             122.924604
# 75%             157.178105
# max             312.372617
# 95% CI Lower     64.917002
# 95% CI Upper    238.365447
# Name: 251, dtype: float64

# %%
# Set initial investment
initial_investment_oneyear = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_lower_oneyear = round(tbl_oneyear[8]*initial_investment_oneyear,2)
ci_upper_oneyear = round(tbl_oneyear[9]*initial_investment_oneyear,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment_oneyear} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_lower_oneyear} and ${ci_upper_oneyear}")
